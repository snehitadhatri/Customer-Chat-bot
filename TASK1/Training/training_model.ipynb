# %%
# !pip install -q streamlit pyngrok joblib scikit-learn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 42.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 73.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.2 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st
import joblib

st.set_page_config(page_title="Real-Time Gen AI Customer Support Bot")

st.title("Customer Service Bot")
st.write("App loaded successfully ✅")

try:
    model = joblib.load("chatbot_model.pkl")
    st.write("✅ Model loaded!")
except Exception as e:
    st.error(f"❌ Error loading model: {e}")

user_input = st.text_input("Enter your message:")

if user_input:
    st.write(f"You typed: {user_input}")
    try:
        prediction = model.predict([user_input])[0]
        st.write(f"🤖 Predicted Intent: **{prediction}**")
    except Exception as e:
        st.error(f"Prediction Error: {e}")
# Out:
# Writing app.py

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc47d52c-1b88-43cf-af63-834980c88af1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc47d52c-1b88-43cf-af63-834980c88af1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ngrok config add-authtoken 30tzdxvePcN5BJ54DB6C3Nlm2y8_7ucJedvRkxyErkhkwmvJs
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
# !streamlit run app.py &> /dev/null &

# Corrected connection method
public_url = ngrok.connect("http://localhost:8501")
print("Your app is live at:", public_url)
# Out:
# Your app is live at: NgrokTunnel: "https://771c5cd94a34.ngrok-free.app" -> "http://localhost:8501"
